# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Ahmed\Downloads\Cleaned_Dataset.csv')

# %%
df.head(10)
# Out:
#    iyear  imonth  iday    country_txt      region_txt    provstate  \
# 0   1970       1     1  United States   North America     Illinois
# 1   1970       1     2  United States   North America   California
# 2   1970       1     2  United States   North America    Wisconsin
# 3   1970       1     3  United States   North America    Wisconsin
# 4   1970       1     6  United States   North America     Colorado
# 5   1970       1     8          Italy  Western Europe        Lazio
# 6   1970       1     9  United States   North America     Michigan
# 7   1970       1     9  United States   North America  Puerto Rico
# 8   1970       1    12  United States   North America     New York
# 9   1970       1    12  United States   North America  Puerto Rico
#
#             city   latitude   longitude                 attacktype1_txt  ...  \
# 0          Cairo  37.005105  -89.176269                   Armed Assault  ...
# ...

# %%
df.dtypes
# Out:
# iyear                 int64
# imonth                int64
# iday                  int64
# country_txt          object
# region_txt           object
# provstate            object
# city                 object
# latitude            float64
# longitude           float64
# attacktype1_txt      object
# targtype1_txt        object
# targsubtype1_txt     object
# natlty1_txt          object
# gname                object
# weaptype1_txt        object
# weapsubtype1_txt     object
# nkill               float64
# nkillus             float64
# nkillter            float64
# nwound              float64
# nwoundus            float64
# nwoundte            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87986 entries, 0 to 87985
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   iyear             87986 non-null  int64
#  1   imonth            87986 non-null  int64
#  2   iday              87986 non-null  int64
#  3   country_txt       87986 non-null  object
#  4   region_txt        87986 non-null  object
#  5   provstate         87986 non-null  object
#  6   city              87986 non-null  object
#  7   latitude          87986 non-null  float64
#  8   longitude         87986 non-null  float64
#  9   attacktype1_txt   87986 non-null  object
#  10  targtype1_txt     87986 non-null  object
#  11  targsubtype1_txt  87986 non-null  object
#  12  natlty1_txt       87986 non-null  object
#  13  gname             87986 non-null  object
#  14  weaptype1_txt     87986 non-null  object
#  15  weapsubtype1_txt  87986 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# iyear               0
# imonth              0
# iday                0
# country_txt         0
# region_txt          0
# provstate           0
# city                0
# latitude            0
# longitude           0
# attacktype1_txt     0
# targtype1_txt       0
# targsubtype1_txt    0
# natlty1_txt         0
# gname               0
# weaptype1_txt       0
# weapsubtype1_txt    0
# nkill               0
# nkillus             0
# nkillter            0
# nwound              0
# nwoundus            0
# nwoundte            0
# dtype: int64

# %%
df.shape
# Out:
# (87986, 22)

# %%
df.describe()
# Out:
#               iyear        imonth          iday      latitude     longitude  \
# count  87986.000000  87986.000000  87986.000000  87986.000000  87986.000000
# mean    2011.235742      6.460619     15.575569     26.911017     49.888730
# std        6.355565      3.386551      8.811803     13.563055     40.428863
# min     1970.000000      1.000000      0.000000    -42.884049   -157.818968
# 25%     2009.000000      4.000000      8.000000     18.389302     37.762325
# 50%     2013.000000      6.000000     15.000000     32.777344     44.679516
# 75%     2015.000000      9.000000     23.000000     34.346722     71.163803
# max     2017.000000     12.000000     31.000000     74.633553    178.441900
#
#               nkill       nkillus      nkillter        nwound      nwoundus  \
# count  87986.000000  87986.000000  87986.000000  87986.000000  87986.000000
# mean       2.013093      0.013661      0.295479      3.676130      0.027777
# ...

# %%
df.corr()
# Out:
#               iyear    imonth      iday  latitude  longitude     nkill  \
# iyear      1.000000 -0.001155  0.022821 -0.042238   0.324595  0.013194
# imonth    -0.001155  1.000000  0.009638  0.006727   0.003299  0.006669
# iday       0.022821  0.009638  1.000000  0.007585   0.008292  0.002133
# latitude  -0.042238  0.006727  0.007585  1.000000  -0.132517  0.004936
# longitude  0.324595  0.003299  0.008292 -0.132517   1.000000 -0.010634
# nkill      0.013194  0.006669  0.002133  0.004936  -0.010634  1.000000
# nkillus   -0.023846  0.000093 -0.000478  0.009735  -0.031827  0.090789
# nkillter   0.039956 -0.000728 -0.004145  0.015390   0.011414  0.409930
# nwound    -0.011697  0.006046  0.000847  0.032358  -0.002071  0.515029
# nwoundus  -0.021166 -0.000987  0.000697  0.006073  -0.026219  0.080202
# nwoundte   0.026062 -0.000559  0.001060  0.017187   0.018084  0.239543
#
#             nkillus  nkillter    nwound  nwoundus  nwoundte
# ...

# %%
sns.regplot(df['nwound'],df['nkill'],fit_reg=False)
# Out:
# C:\Users\Ahmed\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='nwound', ylabel='nkill'>

# %%
sns.regplot(df['nwoundus'],df['nkillus'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='nwoundus', ylabel='nkillus'>

# %%
sns.regplot(df['nwoundus'],df['nkill'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='nwoundus', ylabel='nkill'>

# %%
sns.regplot(df['nwoundte'],df['nkillter'],fit_reg=False)
# Out:
# <AxesSubplot:xlabel='nwoundte', ylabel='nkillter'>

# %%
attacks=df["iyear"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"iyear","iyear":"Attacks"}).set_index("iyear")
attacks.head()
# Out:
#        Attacks
# iyear
# 1970       359
# 1971       136
# 1972        65
# 1973        25
# 1974        33

# %%
attacks.plot(kind="bar",color="cornflowerblue",figsize=(15,6),fontsize=13)
plt.title("Timeline of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %%
df.to_csv('Terrorism Final.csv',index=False)

# %%
img = mpimg.imread('C:/Users/Ahmed/OneDrive/Pictures/Screenshots/Map2.png')
plt.imshow(img)
plt.axis('off')
plt.show()
